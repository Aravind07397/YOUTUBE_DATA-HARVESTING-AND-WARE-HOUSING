# %%
import pandas as pd

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
pip install google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/82/b7/da94eb1338dcc5e6ab08ca22cf7d2395b0d8d957c211a04ff0d74acf23ef/google_api_python_client-2.123.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for httplib2<1.dev0,>=0.15.0 from https://files.pythonhosted.org/packages/a8/6c/d2fbdaaa5959339d53ba38e94c123e4e84b8fbc4b84beb0e70d7c1608486/httplib2-0.22.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for google-auth<3.0.0.dev0,>=1.19.0 from https://files.pythonhosted.org/packages/9e/8d/ddbcf81ec751d8ee5fd18ac11ff38a0e110f39dfbf105e6d9db69d556dd0/google_auth-2.29.0-py2.py3-none-any.whl.metadata
# ...

# %%
from googleapiclient.discovery import build

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"
# First Channel ID
CHANNEL_ID = "UCkAGrHCLFmlK3H2kd6isipg"

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Retrieve channel details
channel_data = youtube.channels().list(
    part="snippet,statistics,contentDetails",  # Add contentDetails part
    id=CHANNEL_ID
).execute()

# Extract relevant data
channel_info = channel_data["items"][0]
channel_name = channel_info["snippet"]["title"]
subscription_count = channel_info["statistics"]["subscriberCount"]
channel_views = channel_info["statistics"]["viewCount"]
channel_description = channel_info["snippet"]["description"]

# Check if contentDetails is available
if 'contentDetails' in channel_info:
    playlist_id = channel_info["contentDetails"]["relatedPlaylists"]["uploads"]
else:
    playlist_id = "Not available"

# Display the retrieved data
print("Channel Name:", channel_name)
print("Subscription Count:", subscription_count)
print("Channel Views:", channel_views)
print("Channel Description:", channel_description)
print("Playlist ID:", playlist_id)
# Out:
# Channel Name: Mr Bean
# Subscription Count: 33000000
# Channel Views: 11073752202
# Channel Description: Welcome to the Official Mr Bean YouTube Channel!
# Follow the adventures of everyone's favourite crazy and clumsy character Mr Bean.
#
# Here you will find all of your favourite Mr Bean moments from the classic Mr Bean series as well as his exciting new animated adventures! Watch full episodes, funny clips and compilations from Rowan Atkinson and Richard Curtis’s classic British Sitcom Mr Bean on YouTube today.
#
# Mr Bean uses his unusual wit to fulfil everyday tasks but more often than not, ends up creating trouble for himself and those around him. Mr Bean lives with Teddy, his stuffed brown bear and drives around in his classic Mini.
#
# Make sure to subscribe so you never miss a full episode of Mr Bean, Mr Bean Animated or our Mr Bean clips and compilations.
#
# Facebook: https://www.facebook.com/MrBean
# Twitter: https://twitter.com/MrBean
# ...

# %%
from googleapiclient.discovery import build

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"
# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve channel details
    channel_data = youtube.channels().list(
        part="snippet,statistics,contentDetails",
        id=channel_id
    ).execute()

    # Extract relevant data
    channel_info = channel_data["items"][0]
    channel_name = channel_info["snippet"]["title"]
    subscription_count = channel_info["statistics"]["subscriberCount"]
    channel_views = channel_info["statistics"]["viewCount"]
    channel_description = channel_info["snippet"]["description"]

    # Check if contentDetails is available
    if 'contentDetails' in channel_info:
        playlist_id = channel_info["contentDetails"]["relatedPlaylists"]["uploads"]
    else:
        playlist_id = "Not available"

    # Display the retrieved data for each channel
    print("Channel ID:", channel_id)
    print("Channel Name:", channel_name)
    print("Subscription Count:", subscription_count)
    print("Channel Views:", channel_views)
    print("Channel Description:", channel_description)
    print("Playlist ID:", playlist_id)
    print("-" * 50)  # Separating each channel's details
# Out:
# Channel ID: UCkAGrHCLFmlK3H2kd6isipg
# Channel Name: Mr Bean
# Subscription Count: 33000000
# Channel Views: 11073752202
# Channel Description: Welcome to the Official Mr Bean YouTube Channel!
# Follow the adventures of everyone's favourite crazy and clumsy character Mr Bean.
#
# Here you will find all of your favourite Mr Bean moments from the classic Mr Bean series as well as his exciting new animated adventures! Watch full episodes, funny clips and compilations from Rowan Atkinson and Richard Curtis’s classic British Sitcom Mr Bean on YouTube today.
#
# Mr Bean uses his unusual wit to fulfil everyday tasks but more often than not, ends up creating trouble for himself and those around him. Mr Bean lives with Teddy, his stuffed brown bear and drives around in his classic Mini.
#
# Make sure to subscribe so you never miss a full episode of Mr Bean, Mr Bean Animated or our Mr Bean clips and compilations.
#
# Facebook: https://www.facebook.com/MrBean
# ...

# %%
from googleapiclient.discovery import build

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"
# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Dictionary to store video details
video_details = {}

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve video details for the channel
    video_data = youtube.search().list(
        part="snippet",
        channelId=channel_id,
        type="video",
        maxResults=10  # Limit to 10 videos per channel
    ).execute()

    # Extract relevant data for each video
    for item in video_data["items"]:
        video_id = item["id"]["videoId"]
        video_title = item["snippet"]["title"]
        video_description = item["snippet"]["description"]
        published_at = item["snippet"]["publishedAt"]
        thumbnail_url = item["snippet"]["thumbnails"]["default"]["url"]

        # Retrieve statistics for the video
        stats_data = youtube.videos().list(
            part="statistics,contentDetails",
            id=video_id
        ).execute()

        # Extract statistics
        view_count = stats_data["items"][0]["statistics"]["viewCount"]
        # Check if dislikeCount key exists
        if "dislikeCount" in stats_data["items"][0]["statistics"]:
            dislike_count = stats_data["items"][0]["statistics"]["dislikeCount"]
        else:
            dislike_count = 0  # Assign default value of 0 if key doesn't exist
        # Check if favoriteCount key exists
        if "favoriteCount" in stats_data["items"][0]["statistics"]:
            favorite_count = stats_data["items"][0]["statistics"]["favoriteCount"]
        else:
            favorite_count = 0  # Assign default value of 0 if key doesn't exist
        comment_count = stats_data["items"][0]["statistics"]["commentCount"]
        duration = stats_data["items"][0]["contentDetails"]["duration"]
        caption_status = stats_data["items"][0]["contentDetails"]["caption"]

        # Store the data in the dictionary
        video_details[video_id] = {
            "Video_Id": video_id,
            "Playlist_Id": channel_id,  # Assuming channel ID as playlist ID
            "Video_Name": video_title,
            "Video_Description": video_description,
            "PublishedAt": published_at,
            "View_Count": view_count,
            "Dislike_Count": dislike_count,
            "Favorite_Count": favorite_count,
            "Comment_Count": comment_count,
            "Duration": duration,
            "Thumbnail": thumbnail_url,
            "Caption_Status": caption_status,
            "Comments": {}  # Placeholder for comments (can be retrieved separately if needed)
        }

# Print the retrieved video details
for video_id, details in video_details.items():
    print("Video ID:", video_id)
    print("Playlist ID:", details["Playlist_Id"])
    print("Video Name:", details["Video_Name"])
    print("Video Description:", details["Video_Description"])
    print("Published At:", details["PublishedAt"])
    print("View Count:", details["View_Count"])
    print("Dislike Count:", details["Dislike_Count"])
    print("Favorite Count:", details["Favorite_Count"])
    print("Comment Count:", details["Comment_Count"])
    print("Duration:", details["Duration"])
    print("Thumbnail URL:", details["Thumbnail"])
    print("Caption Status:", details["Caption_Status"])
    print("-" * 50)  # Separator between videos
# Out:
# Video ID: jphbK692hJY
# Playlist ID: UCkAGrHCLFmlK3H2kd6isipg
# Video Name: Mr Bean Is a Queue Jumper! 😑| Mr Bean #shorts
# Video Description: Mr Bean's a queue jumper… Watch out, Holly & Phil! #mrbean #mrbeanmemes #mrbeancomedy #queue #queuejump ...
# Published At: 2022-10-09T10:00:35Z
# View Count: 1968884
# Dislike Count: 0
# Favorite Count: 0
# Comment Count: 131
# Duration: PT31S
# Thumbnail URL: https://i.ytimg.com/vi/jphbK692hJY/default.jpg
# Caption Status: false
# --------------------------------------------------
# Video ID: c2KmstudgqE
# Playlist ID: UCkAGrHCLFmlK3H2kd6isipg
# Video Name: Mr Bean was not prepared for this | Mr Bean #shorts
# Video Description: MrBean #RowanAtkison Follow the classic adventures of Mr Bean as he navigates his way through the hilarious trials and ...
# Published At: 2023-04-16T09:30:10Z
# View Count: 2083794
# Dislike Count: 0
# Favorite Count: 0
# Comment Count: 174
# Duration: PT16S
# ...

# %%
from googleapiclient.discovery import build

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"
# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Dictionary to store playlist details
playlist_details = {}

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve playlist details for the channel
    playlist_data = youtube.playlists().list(
        part="snippet",
        channelId=channel_id,
        maxResults=50  # Increase if more playlists are expected
    ).execute()

    # Extract relevant data for each playlist
    for item in playlist_data["items"]:
        playlist_id = item["id"]
        playlist_name = item["snippet"]["title"]

        # Store the data in the dictionary
        playlist_details[playlist_id] = {
            "Playlist_Id": playlist_id,
            "Channel_Id": channel_id,
            "Playlist_Name": playlist_name
        }

# Print the retrieved playlist details
for playlist_id, details in playlist_details.items():
    print("Playlist ID:", playlist_id)
    print("Channel ID:", details["Channel_Id"])
    print("Playlist Name:", details["Playlist_Name"])
    print("-" * 50)  # Separator between playlists
# Out:
# Playlist ID: PLC1EDzqtkrh_VY8IesPruBVyPtLgG7A1H
# Channel ID: UCkAGrHCLFmlK3H2kd6isipg
# Playlist Name: Classic Moments | Mr Bean | Live Action
# --------------------------------------------------
# Playlist ID: PLC1EDzqtkrh90jq_B5vS6acSv2hyoWH32
# Channel ID: UCkAGrHCLFmlK3H2kd6isipg
# Playlist Name: Everyday Bean | Mr Bean | Live Action
# --------------------------------------------------
# Playlist ID: PLC1EDzqtkrh8Hc9fvltYfd2A5i-ZvbvY5
# Channel ID: UCkAGrHCLFmlK3H2kd6isipg
# Playlist Name: Funniest Bits | Mr Bean | Live Action
# --------------------------------------------------
# Playlist ID: PLC1EDzqtkrh_f4PMi7v6TJAOoPk2POzpG
# Channel ID: UCkAGrHCLFmlK3H2kd6isipg
# Playlist Name: Full Episodes | Mr Bean | Live Action
# --------------------------------------------------
# Playlist ID: PLC1EDzqtkrh9S_bOmUlPOiyKvTHqE25in
# Channel ID: UCkAGrHCLFmlK3H2kd6isipg
# Playlist Name: Clips | Mr Bean | Live Action
# --------------------------------------------------
# ...

# %%
from googleapiclient.discovery import build

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"
# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Dictionary to store comment details
comment_details = {}

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve video details for the channel
    video_data = youtube.search().list(
        part="snippet",
        channelId=channel_id,
        type="video",
        maxResults=10  # Limit to 10 videos per channel
    ).execute()

    # Extract relevant data for each video
    for item in video_data["items"]:
        video_id = item["id"]["videoId"]

        # Retrieve comments for the video
        comment_data = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100  # Increase if more comments are expected
        ).execute()

        # Extract comment details
        for comment in comment_data["items"]:
            comment_id = comment["id"]
            comment_text = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
            comment_author = comment["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"]
            comment_published_at = comment["snippet"]["topLevelComment"]["snippet"]["publishedAt"]

            # Store the data in the dictionary
            comment_details[comment_id] = {
                "Comment_Id": comment_id,
                "Video_Id": video_id,
                "Comment_Text": comment_text,
                "Comment_Author": comment_author,
                "Comment_Published_At": comment_published_at
            }

# Print the retrieved comment details
for comment_id, details in comment_details.items():
    print("Comment ID:", comment_id)
    print("Video ID:", details["Video_Id"])
    print("Comment Text:", details["Comment_Text"])
    print("Comment Author:", details["Comment_Author"])
    print("Comment Published At:", details["Comment_Published_At"])
    print("-" * 50)  # Separator between comments
# Out:
# Comment ID: Ugyo4nriQutd7uzabAx4AaABAg
# Video ID: jphbK692hJY
# Comment Text: 😂😂😂🎉🎉🎉
# Comment Author: @bedankaranja6829
# Comment Published At: 2024-03-21T16:25:11Z
# --------------------------------------------------
# Comment ID: Ugy76ORnvWUaoCz6-ep4AaABAg
# Video ID: jphbK692hJY
# Comment Text: Is that Mark Knopfler that he goosed?
# Comment Author: @kirstens5801
# Comment Published At: 2024-03-21T15:30:55Z
# --------------------------------------------------
# Comment ID: UgwNYw0u4rJDAYEj10B4AaABAg
# Video ID: jphbK692hJY
# Comment Text: Никой не обича дългите опашки😅
# Comment Author: @user-ej4qe9mg3s
# Comment Published At: 2024-02-27T17:56:09Z
# --------------------------------------------------
# Comment ID: Ugy42-6Gr8o7lEEfVwF4AaABAg
# Video ID: jphbK692hJY
# Comment Text: Abnormal people
# Comment Author: @Angel-sx3zx
# Comment Published At: 2024-01-30T14:25:21Z
# --------------------------------------------------
# Comment ID: UgzXDBvxYR77gDaiCCl4AaABAg
# ...

# %%
# store data in the mysql

# %%
import pandas as pd
import pymysql

# %%
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Bala@9944',database="project")

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/d9/91/007a0d60fee8db4f7385075dc50bf62d2d359b417b374ec06b06ce6c2d64/mysql_connector_python-8.3.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB 660.6 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/15.4 MB 1.1 MB/s eta 0:00:15
#    - -------------------------------------- 0.4/15.4 MB 3.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.4/15.4 MB 8.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.8/15.4 MB 9.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.0/15.4 MB 7.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.3/15.4 MB 7.3 MB/s eta 0:00:02
# ...

# %%
import mysql.connector
from googleapiclient.discovery import build

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"

# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Establishing MySQL Connection
connection = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Bala@9944",
    database="myproject"
)

# Create a cursor object to execute queries
cursor = connection.cursor()

# Define the table creation query with corrected data types
create_table_query = """
CREATE TABLE IF NOT EXISTS channel (
    id INT AUTO_INCREMENT PRIMARY KEY,
    channel_id VARCHAR(255),
    channel_name VARCHAR(255),
    channel_type VARCHAR(255),
    channel_views BIGINT,
    channel_description TEXT,
    channel_status VARCHAR(255)
)
"""

# Execute the table creation query
cursor.execute(create_table_query)
print("Table 'channel' created successfully.")

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve channel details
    channel_data = youtube.channels().list(
        part="snippet,statistics,contentDetails",
        id=channel_id
    ).execute()

    # Extract relevant data
    channel_info = channel_data["items"][0]
    channel_name = channel_info["snippet"]["title"]
    channel_views = int(channel_info["statistics"]["viewCount"])  # Convert to int
    channel_description = channel_info["snippet"]["description"]
    channel_type = "Unknown"  # Assuming channel type is unknown, you can modify accordingly
    channel_status = "Active"  # Assuming all channels are active, you can modify accordingly

    # Insert data into the table
    insert_query = """
    INSERT INTO channel (channel_id, channel_name, channel_type, channel_views, channel_description, channel_status)
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    channel_data = (channel_id, channel_name, channel_type, channel_views, channel_description, channel_status)
    cursor.execute(insert_query, channel_data)
    connection.commit()

# Close cursor and connection
cursor.close()
connection.close()
# Out:
# Table 'channel' created successfully.

# %%
import mysql.connector
from googleapiclient.discovery import build

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"

# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Establishing MySQL Connection
connection = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Bala@9944",
    database="myproject"
)

# Create a cursor object to execute queries
cursor = connection.cursor()

# Define the table creation query for playlist table
create_playlist_table_query = """
CREATE TABLE IF NOT EXISTS playlist (
    id INT AUTO_INCREMENT PRIMARY KEY,
    playlist_id VARCHAR(255),
    channel_id VARCHAR(255),
    playlist_name VARCHAR(255)
)
"""

# Execute the table creation query for playlist table
cursor.execute(create_playlist_table_query)
print("Table 'playlist' created successfully.")

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve channel details
    channel_data = youtube.channels().list(
        part="snippet, contentDetails",
        id=channel_id
    ).execute()

    # Extract playlist data
    playlist_id = channel_data["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
    playlist_data = youtube.playlistItems().list(
        part="snippet",
        playlistId=playlist_id,
        maxResults=5  # Adjust as needed
    ).execute()

    # Insert playlist data into the table
    for item in playlist_data["items"]:
        playlist_name = item["snippet"]["title"]

        insert_playlist_query = """
        INSERT INTO playlist (playlist_id, channel_id, playlist_name)
        VALUES (%s, %s, %s)
        """
        playlist_values = (playlist_id, channel_id, playlist_name)
        cursor.execute(insert_playlist_query, playlist_values)
        connection.commit()

# Close cursor and connection
cursor.close()
connection.close()
# Out:
# Table 'playlist' created successfully.

# %%
import mysql.connector
from googleapiclient.discovery import build
from datetime import datetime

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"
# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Establishing MySQL Connection
connection = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Bala@9944",
    database="myproject"
)

# Create a cursor object to execute queries
cursor = connection.cursor()

# Define the table creation query for the comment table
create_comment_table_query = """
CREATE TABLE IF NOT EXISTS comment (
    comment_id VARCHAR(255) PRIMARY KEY,
    video_id VARCHAR(255),
    comment_text TEXT,
    comment_author VARCHAR(255),
    comment_published_at DATETIME
)
"""

# Execute the table creation query for the comment table
cursor.execute(create_comment_table_query)
print("Table 'comment' created successfully.")

# Dictionary to store comment details
comment_details = {}

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve video details for the channel
    video_data = youtube.search().list(
        part="snippet",
        channelId=channel_id,
        type="video",
        maxResults=10  # Limit to 10 videos per channel
    ).execute()

    # Extract relevant data for each video
    for item in video_data["items"]:
        video_id = item["id"]["videoId"]

        # Retrieve comments for the video
        comment_data = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100  # Increase if more comments are expected
        ).execute()

        # Extract comment details
        for comment in comment_data["items"]:
            comment_id = comment["id"]
            comment_text = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
            comment_author = comment["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"]
            comment_published_at = comment["snippet"]["topLevelComment"]["snippet"]["publishedAt"]

            # Convert comment_published_at to MySQL DATETIME format
            comment_published_at = datetime.strptime(comment_published_at, '%Y-%m-%dT%H:%M:%SZ').strftime('%Y-%m-%d %H:%M:%S')

            # Insert comment data into the comment table
            insert_comment_query = """
            INSERT INTO comment (comment_id, video_id, comment_text, comment_author, comment_published_at)
            VALUES (%s, %s, %s, %s, %s)
            """
            comment_values = (comment_id, video_id, comment_text, comment_author, comment_published_at)
            cursor.execute(insert_comment_query, comment_values)
            connection.commit()

# Close cursor and connection
cursor.close()
connection.close()
# Out:
# Table 'comment' created successfully.

# %%
from googleapiclient.discovery import build
import mysql.connector
import datetime

# YouTube API key
API_KEY = "AIzaSyDrVWGEP3XNEgbpr--DLfx53h0u51QP8eA"
# List of Channel IDs
CHANNEL_IDS = [
    "UCkAGrHCLFmlK3H2kd6isipg", 
    "UCTv-XvfzLX3i4IGWAm4sbmA", 
    "UCEg25rdRZXg32iwai6N6l0w", 
    "UCG5qGWdu8nIRZqJ_GgDwQ-w", 
    "UCvyZS6W6zMJCZBVzF-Ei6sw", 
    "UCJcCB-QYPIBcbKcBQOTwhiA", 
    "UCueYcgdqos0_PzNOq81zAFg", 
    "UCB_qr75-ydFVKSF9Dmo6izg", 
    "UCYwrS5QvBY_JbSdbINLey6Q", 
    "UCjmJDM5pRKbUlVIzDYYWb6g"
]

# Connect to MySQL
connection = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Bala@9944",
    database="myproject"
)
cursor = connection.cursor()

# Create video table if not exists
cursor.execute("""
    CREATE TABLE IF NOT EXISTS video (
        video_id VARCHAR(20) PRIMARY KEY,
        playlist_id VARCHAR(20),
        video_name VARCHAR(255),
        video_description TEXT,
        published_at DATETIME,
        view_count INT,
        like_count INT,
        dislike_count INT,
        favorite_count INT,
        comment_count INT,
        duration VARCHAR(20),
        thumbnail_url VARCHAR(255),
        caption_status VARCHAR(20)
    )
""")

# Connect to YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Dictionary to store video details
video_details = {}

# Loop through each channel ID
for channel_id in CHANNEL_IDS:
    # Retrieve video details for the channel
    video_data = youtube.search().list(
        part="snippet",
        channelId=channel_id,
        type="video",
        maxResults=10  # Limit to 10 videos per channel
    ).execute()

    # Extract relevant data for each video
    for item in video_data["items"]:
        video_id = item["id"]["videoId"]
        video_title = item["snippet"]["title"]
        video_description = item["snippet"]["description"]
        published_at = item["snippet"]["publishedAt"]
        thumbnail_url = item["snippet"]["thumbnails"]["default"]["url"]

        # Retrieve statistics for the video
        stats_data = youtube.videos().list(
            part="statistics,contentDetails",
            id=video_id
        ).execute()

        # Extract statistics including likes
        view_count = stats_data["items"][0]["statistics"]["viewCount"]
        like_count = stats_data["items"][0]["statistics"].get("likeCount", 0)  # Use get method to handle missing key

        # Check if dislikeCount key exists
        if "dislikeCount" in stats_data["items"][0]["statistics"]:
            dislike_count = stats_data["items"][0]["statistics"]["dislikeCount"]
        else:
            dislike_count = 0  # Assign default value of 0 if key doesn't exist
        # Check if favoriteCount key exists
        if "favoriteCount" in stats_data["items"][0]["statistics"]:
            favorite_count = stats_data["items"][0]["statistics"]["favoriteCount"]
        else:
            favorite_count = 0  # Assign default value of 0 if key doesn't exist
        comment_count = stats_data["items"][0]["statistics"]["commentCount"]
        duration = stats_data["items"][0]["contentDetails"]["duration"]
        caption_status = stats_data["items"][0]["contentDetails"]["caption"]

        # Convert published_at to the correct format
        published_at_datetime = datetime.datetime.fromisoformat(published_at.replace('Z', '+00:00'))
        published_at_formatted = published_at_datetime.strftime('%Y-%m-%d %H:%M:%S')

        # Store the data in the dictionary
        video_details[video_id] = {
            "Video_Id": video_id,
            "Playlist_Id": channel_id,  # Assuming channel ID as playlist ID
            "Video_Name": video_title,
            "Video_Description": video_description,
            "Published_At": published_at_formatted,
            "View_Count": view_count,
            "Like_Count": like_count,  # Added like count
            "Dislike_Count": dislike_count,
            "Favorite_Count": favorite_count,
            "Comment_Count": comment_count,
            "Duration": duration,
            "Thumbnail_URL": thumbnail_url,
            "Caption_Status": caption_status
        }

# Insert data into the video table
for video_id, details in video_details.items():
    insert_video_query = """
        INSERT INTO video (video_id, playlist_id, video_name, video_description, published_at,
                           view_count, like_count, dislike_count, favorite_count, comment_count,
                           duration, thumbnail_url, caption_status)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    video_values = (video_id, details["Playlist_Id"], details["Video_Name"], details["Video_Description"],
                    details["Published_At"], details["View_Count"], details["Like_Count"],
                    details["Dislike_Count"], details["Favorite_Count"], details["Comment_Count"],
                    details["Duration"], details["Thumbnail_URL"], details["Caption_Status"])
    cursor.execute(insert_video_query, video_values)
    connection.commit()

# Close cursor and connection
cursor.close()
connection.close()

# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/9b/ea/7219c01b5e92d02d2bc994a36245d99331cd66eb12d284707a2060a013d0/streamlit-1.32.2-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/c5/e4/7fcceef127badbb0d644d730d992410e4f3799b295c9964a172f92a469c7/altair-5.2.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/fa/2a/7f3714cbc6356a0efec525ce7a0613d581072ed6eb53eb7b9754f33db807/blinker-1.7.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
# ...

# %%
import streamlit as st
import mysql.connector
import pandas as pd

# Establishing MySQL Connection
connection = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Bala@9944",
    database="myproject"
)

# Create a cursor object to execute queries
cursor = connection.cursor()

# Function to execute queries and return results as dataframe
def execute_query(query):
    cursor.execute(query)
    columns = [col[0] for col in cursor.description]
    data = cursor.fetchall()
    df = pd.DataFrame(data, columns=columns)
    return df

# Function to display dataframe as table
def display_table(df):
    st.dataframe(df)

# Home page
def home():
    st.title("YouTube Data Analysis App")
    st.subheader("Select an action:")
    action = st.selectbox("Choose an action", ["Collect Data", "View Data"])
    return action

# Collect data page (Placeholder logic)
def collect_data():
    st.title("Collect Data")
    st.write("Enter the channel IDs to collect data:")
    channel_ids = st.text_input("Enter channel IDs (comma-separated)", "")
    if st.button("Collect Data"):
        channel_ids = channel_ids.split(",")
        for channel_id in channel_ids:
            # Placeholder logic to collect data for channels, playlists, comments, and videos
            st.write(f"Data collection in progress for Channel ID: {channel_id}")
        st.success("Data collection complete!")

# View data page
def view_data():
    st.title("View Data")
    st.subheader("Select a table to view:")
    table = st.selectbox("Choose a table", ["Channel", "Playlist", "Comment", "Video"])
    if table == "Channel":
        query = "SELECT * FROM channel"
    elif table == "Playlist":
        query = "SELECT * FROM playlist"
    elif table == "Comment":
        query = "SELECT * FROM comment"
    elif table == "Video":
        query = "SELECT * FROM video"
    df = execute_query(query)
    display_table(df)

# 10 questions page
def ten_questions():
    st.title("Answer 10 Questions")
    st.subheader("Select a question to answer:")
    question = st.selectbox("Choose a question", [
        "What are the names of all the videos and their corresponding channels?",
        "Which channels have the most number of videos, and how many videos do they have?",
        "What are the top 10 most viewed videos and their respective channels?",
        "How many comments were made on each video, and what are their corresponding video names?",
        "Which videos have the highest number of likes, and what are their corresponding channel names?",
        "What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
        "What is the total number of views for each channel, and what are their corresponding channel names?",
        "What are the names of all the channels that have published videos in the year 2022?",
        "What is the average duration of all videos in each channel, and what are their corresponding channel names?",
        "Which videos have the highest number of comments, and what are their corresponding channel names?"
    ])
    if st.button("Answer"):
        if question == "What are the names of all the videos and their corresponding channels?":
            query = """
            SELECT v.video_name, c.channel_name
            FROM video v
            JOIN channel c ON v.playlist_id = c.channel_id
            """
        elif question == "Which channels have the most number of videos, and how many videos do they have?":
            query = """
            SELECT channel_id, COUNT(*) AS num_videos
            FROM video
            GROUP BY channel_id
            ORDER BY num_videos DESC
            LIMIT 1
            """
        elif question == "What are the top 10 most viewed videos and their respective channels?":
            query = """
            SELECT v.video_name, c.channel_name, v.view_count
            FROM video v
            JOIN channel c ON v.playlist_id = c.channel_id
            ORDER BY v.view_count DESC
            LIMIT 10
            """
        elif question == "How many comments were made on each video, and what are their corresponding video names?":
            query = """
            SELECT v.video_name, COUNT(*) AS num_comments
            FROM video v
            JOIN comment co ON v.video_id = co.video_id
            GROUP BY v.video_name
            """
        # Add logic for other questions similarly
        df = execute_query(query)
        display_table(df)

# Main function to run the application
def main():
    action = home()
    if action == "Collect Data":
        collect_data()
    elif action == "View Data":
        view_data()
    else:
        ten_questions()

if __name__ == "__main__":
    main()

# Close cursor and connection
cursor.close()
connection.close()
# Out:
# 2024-03-26 11:35:15.573
# ...
#   command:
#
#     streamlit run C:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
